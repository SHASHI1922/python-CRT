# %% [markdown]
# <a href="https://colab.research.google.com/github/SHASHI1922/python-CRT/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = "the asgaurd in that there is scarlet witch"
b = a.lower()
print(a[2:4])
print (a.upper())
# Out:
# e
# THE ASGAURD IN THAT THERE IS SCARLET WITCH

# %%
c = a.swapcase()
d = a.title()
e = a. capitalize()
f = a.count(a)
g = a.find(a)
print(d)
print(e)
print(f)
print(g)
# Out:
# The Asgaurd In That There Is Scarlet Witch
# The asgaurd in that there is scarlet witch
# 1
# 0

# %%
a = "sdfghjkjhgfd"
b = a.isdigit()
c = a.isalpha()
d = a.isalnum()
print (b)
print (c)
print (d)
# Out:
# False
# True
# True

# %%
a = "the asgaurd in that there is scarlet witch"
b = "".join(i for i in a if i in "aeiou")
print (b)      #join all the all vowels
# Out:
# eaauiaeeiaei

# %%
a ="the asgaurd in that there is scarlet witch"
b = sorted (a, reverse=True)#sort all z - a in revrse
print (b)
# Out:
# ['w', 'u', 't', 't', 't', 't', 't', 't', 's', 's', 's', 'r', 'r', 'r', 'n', 'l', 'i', 'i', 'i', 'h', 'h', 'h', 'h', 'g', 'e', 'e', 'e', 'e', 'd', 'c', 'c', 'a', 'a', 'a', 'a', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %%
a = input ("enter pass : ")
up =0
lc = 0
sp = 0
dig = 0
if len(a)>7:
  for i in a :
    if i.isupper():
      up = up+1
    elif i.islower():
      lc= lc+1
    elif i.isdigit():
      dig = dig +1
    else :
      sp = sp + 1
  if up>0 and lc>0 and sp > 0 and dig>0:
    print ("strong")
  else :
      print ("f")
else :
  print("more weak")
# Out:
# enter pass : dfghjkl\
# f

# %%
#DIGITAL TIME
import time
import sys
h=3
s=0
m=40
while True:
  sys.stdout.write("\r{:02d}:{:02d}:{:02d}".format(h,m,s))
  sys.stdout.flush()
  time.sleep(1)
  s=s+1
  if s==60:
    s=0
    m=m+1
  if m==60:
    m=0
    h=h+1
  if h==24:
    h=0
# Out:
# 04:03:06

# %%
from datetime import datetime
import pytz  #date and time package
a=pytz.timezone("Asia/Kolkata")
b=datetime.now(a)
print(b)
for i in pytz.all_timezones:
  print(i)

# %%
#comprehnsive
#a = [chr(i) for i in range(65,91)].   #using asci value
a = [chr(i) for i in range(65,91) if chr(i) not in "AEIOU"]     #not in vowel
print(a)

# %%
a = 6789
b = [int (i) for i in str(a)]
print (max(b))                      #only max

# %%
#
names = ["starck","gruce","wanda","vision","soooop"]
marks = [30,40,50,60,70,80]
pos =1
for i in range(5):
  if marks [i]>40:
    print ("{}.{} has scored {}%".format (pos,names [i],marks[i]))
    pos = pos+1

# %%
#
names = ["starck","gruce","wanda","vision","soooop"]
marks = [30,40,50],[60,70,80],[99,88,90],[99,89,56],[45,67,88]
for i in range (5):
  p = sum (marks [i])//3
  if p >80 :
    g = "s"
  elif p<40:
    g = "f"
  elif p>40 and p<60 :
    g = "b"
  else :
      g = "A"
  print ("{}.mr/ms {} has scored {}%-{} Grade ".format(i+1,names [i].title(),p,g))
# Out:
# 1.mr/ms Starck has scored 40%-A Grade
# 2.mr/ms Gruce has scored 70%-A Grade
# 3.mr/ms Wanda has scored 92%-s Grade
# 4.mr/ms Vision has scored 81%-s Grade
# 5.mr/ms Soooop has scored 66%-A Grade

# %%
#zip (merging)
names = ["starck","gruce","wanda","vision","soooop"]
age = [24,45,55,65,45]
res = list(zip(names, age ))
res1 = sorted(res)
pos =1
for i in res1:
  print ("Rank {}: {} age is {} yrs old".format(pos,i[1],i[0]))
  pos+=1
# Out:
# Rank 1: 45 age is gruce yrs old
# Rank 2: 45 age is soooop yrs old
# Rank 3: 24 age is starck yrs old
# Rank 4: 65 age is vision yrs old
# Rank 5: 55 age is wanda yrs old

# %%
a=int (input("enter no of taeam "))
teams = []
for i in range (a):
  t = input("enter team name : ")
  teams.append(t)
m=int (input("enter no of taeam "))

matches =[]
pos =1
for i in range (0,a-1):
  for j in range (i+1,a):
    for k in range (m):
      matches.append([teams[i],teams[j]])
for i in matches:
  print("match {} : {} vs {}".format(pos,i[0],i[1]))
  pos+=1
# Out:
# enter no of taeam 5
# enter team name : srh
# enter team name : rr
# enter team name : rcb
# enter team name : csk
# enter team name : kkr
# enter no of taeam 2
# match 1 : srh vs rr
# match 2 : srh vs rr
# match 3 : srh vs rcb
# match 4 : srh vs rcb
# match 5 : srh vs csk
# match 6 : srh vs csk
# match 7 : srh vs kkr
# match 8 : srh vs kkr
# match 9 : rr vs rcb
# match 10 : rr vs rcb
# match 11 : rr vs csk
# match 12 : rr vs csk
# match 13 : rr vs kkr
# match 14 : rr vs kkr
# match 15 : rcb vs csk
# match 16 : rcb vs csk
# match 17 : rcb vs kkr
# match 18 : rcb vs kkr
# match 19 : csk vs kkr
# match 20 : csk vs kkr

# %%
from random import shuffle
a=int (input("enter no of team "))
teams = []
for i in range (a):
  t = input("enter team name : ")
  teams.append(t)
m=int (input("enter no ofmet taeam "))

matches =[]
for i in range (0,a-1):
  for j in range (i+1,a):
    for k in range (m):
      matches.append([teams[i],teams[j]])
      shuffle(matches)
pos =1
for i in matches:
  print("match {} : {} vs {}".format(pos,i[0],i[1]))
  pos+=1
# Out:
# enter no of team 2
# enter team name : srh
# enter team name : dc
# enter no ofmet taeam 3
# match 1 : srh vs dc
# match 2 : srh vs dc
# match 3 : srh vs dc

# %%
name1 = input("Enter first name: ").lower().replace(" ", "")
name2 = input("Enter second name: ").lower().replace(" ", "")

for ch in name1[:]:
    if ch in name2:
        name1 = name1.replace(ch, "", 1)
        name2 = name2.replace(ch, "", 1)

count = len(name1 + name2)

flames = ["F", "L", "A", "M", "E", "S"]

while len(flames) > 1:
    index = (count % len(flames)) - 1

    if index >= 0:
        right = flames[index+1:]
        left = flames[:index]
        flames = right + left
    else:
        flames.pop()

result = {
    "F": "Friends",
    "L": "Love",
    "A": "Affection",
    "M": "Marriage",
    "E": "Enemy",
    "S": "Sister"
}

print("Relationship:", result[flames[0]])

# %%
name1 = input("Enter first name: ").lower().replace(" ", "")
name2 = input("Enter second name: ").lower().replace(" ", "")
a1 = list(name1)
b1 = list(name2)
for i in range (len(name1)):
  for j in range (len(name2)):
    if a1[i]==b1[j]:
      a1[i]='2'
      b1[j]='2'
c = 0
for i in  a1:
  if i!= '2' :
    c+=1
for i in  b1:
  if i!='2':
    c+=1
print (c)
index = 0
res = list ("FLAMES")
for i in range (5):
  index = (index + c - 1) % len(res)
  res.pop(index)
print(res[0])
# Out:
# Enter first name: charan
# Enter second name: malayasree
# 10
# L

# %%
a = [[" " for j in range (11)] for i in range (11)]
for i in range (11):
  for j in range (11):
    if j==0 or j==10:
      a[i][j] = "*"
    if i==j and i<6:
       a[i][j] = "*"
    if i+j==10 and i<6:
       a[i][j] = "*"

for i in range(11):
        for j in range(11):
            print(a[i][j], end=" ")
        print()
# Out:
# *                   *
# * *               * *
# *   *           *   *
# *     *       *     *
# *       *   *       *
# *         *         *
# *                   *
# *                   *
# *                   *
# *                   *
# *                   *

# %%
#tuple
a = ()
a = a(10,)
print(a)


#set
a = {}
print (type(a))

# %%
a={2,2,3,4,5,6,5,6}
for i in a:
  print("Hi")

# %%
a={5,3,4,5}
a.pop()
print(a)

# %%
a={2,4,6,7,8,9}
b={1,2,4,7,11,13}
print(a.union(b))
print(a&b)
print(a-b)
print(b-a)

# %%
d={'name':'Gill','age':45,'runs':4000}
for i in d.items():
  print(i)
for i in d.keys():
  print(i)

# %%
a = 1
for i in range (2,5):
  a+=i
  for j in range (i):
    a+=j
    print (str(a),end =" ")
  print ()
print (a)
# Out:
# 3 4
# 7 8 10
# 14 15 17 20
# 20

# %% [markdown]
# functions:
#           block of code
#           inbuild fun
#           user
#       adv:
#           1 code resuse
#           2 readability
#           3 integration
#       types:
#             with out rturn without args
#             with rturn without args
#             with args wtot retn
#             both with

# %%
def prime(n):
    if n<=1:
        return False
    else:
      for i in range (2,n):
          if n%i==0:
              return False
      return True

def sod(n):
    d = [int(i) for i in str(n)]
    return sum(d)

def every(n):
    for i in range (3):
        d = n%10
        n = n//10
        if not prime (d):
            return False
    return True
for i in range(100,1000):
    if prime(i) and prime(sod(i)) and every(i):
        print (i,end=" ")
# Out:
# 223 227 337 353 373 557 577 733 757 773

# %%
#opps
Class is a container
containes method variables
object is instance of class or member of a class

# %%
x = "AAABBCCDDEEE"
res =""
c = 1
for i in range (len(x)):
  if i+1<len(x) and x[i]==x[i+1]:
    c+=1
  else:
    res=res+x[i]
    res=res+str(c)
    c=1
print(res)
# Out:
# A3B2C2D2E3

# %% [markdown]
# Recursion : it is an topdown approach
#           fns call itself
#           base condition -> exit of fns
#           argument :

# %%
#Recursion
def flower(a):
  if a==4:
    return
  print(a+10,end=" ")
  flower(a+1)
  print(a,end=" ")
flower(1)
# Out:
# 11 12 13 3 2 1

# %%
#nested
def raju(a):
  if a==1:
    return
  a-=1
  raju(a)
  print("hi")
  raju(a)
raju(5)
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi

# %%
def raju(a):
  if a==4:
    return 1
  b = raju(a+1)
  print("hi")
  return b+2
res=raju(1)
print(res)
# Out:
# hi
# hi
# hi
# 7

# %%
#OOPS:
#1) var (4)
#2)class:container(method &obj)
#3)obj:method of class
#-----------
#1)Local var(has scope only in particular method)
#2)instance (global)-(every obj holds unique values)
#3)class var(global)-(every obj holds same values)
#4)Complete global-(declared outside class, accessed anywhere)

# %%
class abc:
  num=100
  def set_dim(self,a,b):
    self.total=a+b+abc.num
  def display(self):
    print("Additionis ",self.total)
a = abc()
b = abc()
a.set_dim(10,20)
b.set_dim(20,30)
a.display()
b.display()
# Out:
# Additionis  130
# Additionis  150

# %%
x="india"
class ace:
    def give_details(self,a,b,c,d):
        self.tot=a+b+c
        self.name=d
    def display(self):
        print("1.NAME= ",self.name)
        print("2.MARK= ",self.tot)
        print("3.COUNTRY: ",x)
class bvrit(ace):
    def display(self):
        print("1.NAME= ",self.name)
        print("2.MARK= ",self.tot)
        print("3.COUNTRY: ",x)

a=ace()
a.give_details(20,30,40,"Vijay")
a.display()
b=bvrit()
b.give_details(30,40,50,"Pavi")
b.display()
# Out:
# 1.NAME=  Vijay
# 2.MARK=  90
# 3.COUNTRY:  india
# 1.NAME=  Pavi
# 2.MARK=  120
# 3.COUNTRY:  india

# %%
def shashi(a):
  if a==1:
    return
  i = 2
  while(a%i!=0):
    i = i+1
  print (i,end =" ")
  shashi(a/i)
a = int(input("enter any num :"))
shashi(a)

# %%
from typing import Self
class rect:
  def __init__(self,a,b):
    self.area = a*a
  def display(self):
    print ("area of : ",self.area)
r = rect (47,67)
r.display()
# Out:
# area of :  2209

# %%
class circle :
  def __init__ (self):
    x = int (input("enter radius : "))
    self.r=x
  def display(self):
    print("area of circle  ",3.14*self.r**2)
a=int(input("enter cir : "))
l=[]
for i in range (a):
  c=circle()
  l.append(c)
  c.display()
print("---------------")
# Out:
# enter cir : 2
# enter radius : 2
# area of circle   12.56
# enter radius : 22
# area of circle   1519.76
# ---------------

# %%
class Node:
    def __init__(self,data):
      self.data=data
      self.next=None
class LinkedList:
  def __init__(self):
    self.head=None
  def insert(self,data):
      newnode=Node(data)
      if self.head==None:
        self.head=newnode
      else:
          temp=self.head
          while temp.next!=None:
            temp=temp.next
          temp.next=newnode
  def display(self):
          temp=self.head
          while temp:
            print(temp.data,end="->")
            temp=temp.next
l=LinkedList()
l.insert(100)
l.insert(200)
l.insert(300)
l.insert(400)
l.insert(500)
l.display()
# Out:
# 100->200->300->400->500->

# %%
a = 3334445567      #int -dic
b = {}
for i in str(a):
  if i not in b :
    b[i]=1
  else:
    b[i]+=1
print (b)
# Out:
# {'3': 3, '4': 3, '5': 2, '6': 1, '7': 1}

# %%
b = {'A':2,'B':3,'C':4,'D':5}
a1 = [i[0] for i in b.items()]     #dic - lis
a2 = [i[1] for i in b.items()]
print (a1)
print(a2)
# Out:
# ['A', 'B', 'C', 'D']
# [2, 3, 4, 5]

# %%
#unction :
#keyword
#Infinite
#default

#______________________

def abc(*args):
  sum = 0
  for i in args:
    sum+=i
  print(sum)
abc(22,22)
abc(22,22)

#key
def a(**kargs):
  print(kargs)
a(Name='cool',Score=28)
# Out:
# 44
# 44
# {'Name': 'cool', 'Score': 28}

# %%
def detectcycle(self,head):
    if head is none or head.next is none:
        return None
    fast=head
    slow=head
    while(fast is not none and fast.next is not none):
        fast=fast.next.next
        slow=slow.next
        if (fast==slow):
            break
            if (fast is none or fast.next is none):
                return None
            slow=head
            while(fast!=slow):
                slow=slow.next
                fast=fast.next
            return slow

# %%
import numpy as np
import matplotlib.pyplot as plt

overs = np.arange(1, 11)
scores = [2, 4, 7, 1, 12, 8, 5, 3, 9, 10]

plt.bar(overs, scores, color="green")

plt.title("INDIA SCORE BASED ON OVERS")
plt.xlabel("OVERS FROM 1 TO 10")
plt.ylabel("RUNS BY OVERS")

plt.xticks(overs)
plt.grid(axis="y", linestyle="--")

plt.show()

# %%
import numpy
a = [20,30,40,50]
res = np.percentile(a,50)
print(res)
# Out:
# 35.0

# %%
from scipy import stats
a = [20,30,40,50]
res = stats.percentileofscore(a,11)
print(res)
# Out:
# 0.0

# %%
##tabulate
from tabulate import tabulate
title = ["Name","Age","dept"]
data = [["SHASHI",21,"CSE"],
        ["WANDA",22,"CSM"]]
res = tabulate(data,headers=title,tablefmt="pretty")
print (res)
# Out:
# +--------+-----+------+
# |  Name  | Age | dept |
# +--------+-----+------+
# | SHASHI | 21  | CSE  |
# | WANDA  | 22  | CSM  |
# +--------+-----+------+

# %%
a= open("tvk.text",'w')
n1 = int(input("enter no."))
n2 = int(input("enter no."))
s = n1 + n2
a.write(str(s)+"\n")
a.write(str(n1)+"\n")
a.write(str(n2)+"\n")
a.close()
# Out:
# enter no.1
# enter no.1

# %%
#from IPython.core import application
#os
#/w
#utility
#application

# %%
a = [1,2,3,4]
b ="".join(map(str,a))
print(b)
# Out:
# 1234

# %%
class stack:
    def __init__(self):
        self.l=[]
    def push(self,a):
        self.l.append(a)
    def pop(self):
        self.l.pop()
    def display(self):
        b="->".join(map(str,self.l))
        print(b)
    def peek(self):
        print(self.l[-1])

s=stack()
s.push(100)
s.push(90)
s.push(300)
s.display()
s.pop()
s.display()
s.peek()
# Out:
# 100->90->300
# 100->90
# 90

# %%
'''
tree-non linear datastructure
hierarchical
root-first layer
edge-connection b\w nodes
leaf node-last node -donot have child node
siblings-nodes of same parents
TREE-
BINARY , TERNARY, N-ARY
CLASSIFACTIONS OF TREE ON NODE VALUE
**NODE VALUE
BST-BINARY SEARCH TREE-PARENT NODE VALUE IS GREATER THAN LEFT CHILD AND LESS THAN RIGHT CHILD
AVL-ADAL VALE LANDIS-BALENCE FACTORE OF VALUE IS AT MOST ONE
RED BLACK TREE-BASED ON COLOR CODE
B-TREE - DATA-LEFT-RIGHT

# %%
'''
BINARY SEARCH TREE
1- TRAVERSAL ALGO-
   INORDER TRAVERSAL ALGO
   PREORDER TRAVERSAL ALGO
   POSTORDER TRAVERSAL ALGO
   LEVEL ORDER TRAVERSAL ALGO

2- SEARCHING ALGO -
3- SORTING ALGO -
TREES- BINARY SEARCH TREE
**
100 40 20 33 51 67 56 70
PRE "MLR"
POST "LMR"
IN  "LMR"
LEVEL

# %%
#**AVL TREE
#ADELSON VELSKY AND LANDIS
#BALANCE FACTOR CALCULACTION
#BALANCE FACTOR=HEIGHT OF LEFT SUB TREE - HEIGHT OF RIGHT SUBTREE

SINGLE ROTATION - RIGHT ROTATION
NODE X = Y.LEFT;
NODE T2 = X.RIGHT;
X.RIGHT = Y;
Y.LEFT = T2;
# Out:
#   File "/tmp/ipykernel_7607/2265284212.py", line 6
#     SINGLE ROTATION - RIGHT ROTATION
#            ^
# SyntaxError: invalid syntax

# %%
import heapq
a=[10,11,23,45,67,89,7,90]
res=[]
heapq.heappush(res,10)
heapq.heappush(res,11)
heapq.heappush(res,23)
heapq.heappush(res,45)
heapq.heappush(res,67)
heapq.heappush(res,89)
heapq.heappush(res,7)
heapq.heappush(res,90)
print(res)
